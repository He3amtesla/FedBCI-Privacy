# %%
import torch
import numpy as np

# %%
data = [[1,2], [3,4], [5,6]]
x_data = torch.tensor(data)

# %%
np_array = np.array (data)
x_np = torch.from_numpy(np_array)

# %%
x_ones = torch.ones_like(x_data) # retains the properties of x_data
print(f"Ones Tensor: \n {x_ones} \n")

x_rand = torch.rand_like(x_data, dtype=torch.intger) # overrides the datatype of x_data
print(f"Random Tensor: \n {x_rand} \n")
# Out:
# Ones Tensor:
#  tensor([[1, 1],
#         [1, 1],
#         [1, 1]])
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipython-input-3460895860.py in <cell line: 0>()
#       2 print(f"Ones Tensor: \n {x_ones} \n")
#       3
# ----> 4 x_rand = torch.rand_like(x_data) # overrides the datatype of x_data
#       5 print(f"Random Tensor: \n {x_rand} \n")
#
# NotImplementedError: "check_uniform_bounds" not implemented for 'Long'
